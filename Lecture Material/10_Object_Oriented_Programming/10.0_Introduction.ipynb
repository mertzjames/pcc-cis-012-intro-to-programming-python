# %% [markdown]
# # Object Oriented Programming (OOP)

# %% [markdown]
# ## Module Outline
#
# 1. What is Object Oriented Programming?
# 1. Understanding Objects
# 1. Object factories using classes
# 1. Working with custom classes
# 1. Understanding Inheritance

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# I've got in my hands some pokemon cards, each one describing a specific pokemon and its attributes and abilites.  Each one is pretty different, but they all have some things in common.  What if I wanted model these in Python, maybe even create a simulator for battling?  How would I go about doing that?  I could use a list, with each element within the list representing an attribute value or even function, but that gets really messy real quick.  I could use a dictionary but after creating a few pokemon my hands are going to start hurting and it feels like I'm just repeating myself.
#
# There's another way we can do this and that's through the use of Object Oriented Programming (OOP).  In this module we're going to learn about OOP, it's core concepts, and the basics of how to use it in Python.

# %% [markdown]
# ## Learning Objectives
#
# After completing this module you'll learn:
#
# - What an object is.
# - How to create an instance of an object.
# - Understanding the "type" of an object.
# - The object lifecycle.
# - What a class is.
# - How to create you own objects using custom classes.
# - Class properties and methods.
# - The differences between class and instance properties.
# - Creating multiple instances of a class.
# - Class inheritance.
# - The difference between a Parent and a Child class.
# - Dunder methods such as `__str__`.
